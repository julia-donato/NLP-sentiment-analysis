# %%
import json
import nltk
import spacy
from nltk.corpus import sentiwordnet as swn, stopwords
from nltk.tokenize import word_tokenize, WordPunctTokenizer
from nltk.tag import pos_tag
from nltk.corpus import wordnet
import warnings
warnings.filterwarnings('ignore')

# Initialize spacy for lemmatization
nlp = spacy.load('en_core_web_sm')

# Mapping to SentiWordNet POS tags
mapping = {'NN': 'n', 'JJ': 'a', 'VB': 'v', 'RB': 'r'}

def tag_pos(tag):
    if tag in mapping.keys():
        return mapping[tag]
    else:
        return None

stop_words = stopwords.words('english')

with open('AMAZON_FASHION.json', 'r') as f:
    for ids, line in enumerate(f):
        if ids == 100:  #100 reviews
            break

        review = json.loads(line)

        # Tokenize and POS tag the review text
        doc = nlp(review['reviewText'])
        lemmatized_sentence = " ".join([token.lemma_ for token in doc])
        tokens = word_tokenize(lemmatized_sentence)
        tagged_tokens = pos_tag(tokens)

        pos_score = neg_score = obj_score = 0

        # Calculate sentiment scores
        for word, tag in tagged_tokens:
            wn_tag = tag_pos(tag[:2])
            if word not in stop_words and wn_tag is not None:
                synsets = list(swn.senti_synsets(word, wn_tag))
                if synsets:
                    synset = synsets[0]
                    pos_score += synset.pos_score()
                    neg_score += synset.neg_score()
                    obj_score += synset.obj_score()

        if pos_score > neg_score:
            overall_sentiment = "Positive"
        elif pos_score < neg_score:
            overall_sentiment = "Negative"
        else:
            overall_sentiment = "Neutral"

        print(f"Review: {review['reviewText']}")
        print(f"Rating: {review['overall']}")
        print(f"Positive score: {pos_score}")
        print(f"Negative score: {neg_score}")
        print(f"Objective score: {obj_score}")
        print(f"Overall Sentiment: {overall_sentiment}\n")
   
        df = df.append({
            'Review': review['reviewText'],
            'Rating': review['overall'],
            'Positive_score': pos_score,
            'Negative_score': neg_score,
            'Objective_score': obj_score,
            'Overall_sentiment': overall_sentiment
        }, ignore_index=True)

df.to_csv('sentiment_scores.csv', index=False)
# Out:
# Review: Exactly what I needed.
# Rating: 5.0
# Positive score: 0.375
# Negative score: 0.25
# Objective score: 1.375
# Overall Sentiment: Positive
#
# Review: I agree with the other review, the opening is too small.  I almost bent the hook on some very expensive earrings trying to get these up higher than just the end so they're not seen.  Would not buy again but for the price, not sending back.
# Rating: 2.0
# Positive score: 0.875
# Negative score: 0.625
# Objective score: 15.5
# Overall Sentiment: Positive
#
# Review: Love these... I am going to order another pack to keep in work; someone (including myself) is always losing the back to an earring.  I don't understand why all fish hook earrings don't have them.  Just wish that they were a tiny bit longer.  :)
# Rating: 4.0
# Positive score: 0.375
# Negative score: 0.875
# Objective score: 14.75
# Overall Sentiment: Negative
#
# Review: too tiny an opening
# Rating: 2.0
# Positive score: 0.0
# Negative score: 0.0
# Objective score: 2.0
# Overall Sentiment: Neutral
#
# Review: Okay
# Rating: 3.0
# Positive score: 0.125
# Negative score: 0.125
# Objective score: 0.75
# Overall Sentiment: Neutral
#
# Review: Exactly what I wanted.
# Rating: 5.0
# Positive score: 0.375
# Negative score: 0.0
# Objective score: 1.625
# Overall Sentiment: Positive
#
# Review: These little plastic backs work great.  No more loosing "hook" earrings!  Wish I had ordered these sooner before I had lost some of my favorite earrings!
# Rating: 4.0
# Positive score: 0.125
# Negative score: 0.5
# Objective score: 10.375
# Overall Sentiment: Negative
#
# Review: mother - in - law wanted it as a present for her sister. she liked it and said it would work.
# Rating: 3.0
# Positive score: 0.25
# Negative score: 0.125
# Objective score: 5.625
# Overall Sentiment: Positive
#
# Review: Item is of good quality. Looks great, too. But it does not fit 100's! But it can be stretched to fit them if you carefully push bottom of case with your fingers. Then shove in a pack of 100's(max) and level it out as you close case stretching case closed. Leave a pk.in it for month or so & was la! Buxton is usually a good quality product!
# Rating: 3.0
# Positive score: 3.75
# Negative score: 0.375
# Objective score: 21.875
# Overall Sentiment: Positive
#
# Review: I had used my last el-cheapo fake leather cigarette case for SEVEN YEARS. It still closed completely but the plastic made to look like leather was literally falling off, so it was time for a new one. Cigarette cases for kings size cigs are not easy to come by these days I discovered, but I was thrilled to find this one on Amazon. It was a great price, REAL LEATHER, and even had the cool zipper pouch on the back. I was so excited to get my case and toss that other one! Well, within THREE DAYS one of the gold clasps literally broke off! I couldn't believe it! I tried to super glue it back on and was not successful. so, I still use the case but it doesn't close securely. I was very disappointed that my $3.00 plastic one lasted 7 years and this real nice leather one lasted 3 days!! But I still love the zipper pouch on the back, it's great for the spare key to my car because I will not go ANYWHERE without my cigarettes!
# Rating: 3.0
# Positive score: 6.25
# Negative score: 3.0
# Objective score: 66.75
# Overall Sentiment: Positive
#
# Review: This brand has been around a long time and you can count on good quality merchandise.  Held up well with no rips or stitching problems!
# Rating: 4.0
# Positive score: 1.5
# Negative score: 0.75
# Objective score: 9.75
# Overall Sentiment: Positive
#
# Review: I smoke 100's and these are NOT made for them.  I can get my cigarettes in it but it won't close. I was very disappointed.
# Rating: 2.0
# Positive score: 0.125
# Negative score: 0.5
# Objective score: 5.375
# Overall Sentiment: Negative
#
# Review: cheap and cheesy, but i guess i could have expected that for the price, won't purchase another without seeing first
# Rating: 1.0
# Positive score: 0.125
# Negative score: 0.0
# Objective score: 4.875
# Overall Sentiment: Positive
#
# Review: I ordered a ladies cigarette case for my wife, and a pack of Marlboro 100's would not fit in the case!!!!  I was ripped off!!!  A cigarette case should be able to hold any cigarette pack!!!!  I will not do business with Silverhooks again!!!!
#
# It's not even worth the postage to send it back!!!!
#
# Dissatisfied big time!!!!
# Rating: 1.0
# Positive score: 1.375
# Negative score: 0.875
# Objective score: 19.75
# Overall Sentiment: Positive
#
# Review: Received the case in less than a week...was very satisfied with the product...only one problem...not really a problem with product, but with price as inside the product was a Buxton tag that showed sugg retail at $9.99 and I paid $11.99.  Hmmm...didn't quite understand this, but what are you going to do?!  Beware...as I think that had I gone to the Buxton web site I may have been able to obtain the same product for the sugg retail price.
# Rating: 4.0
# Positive score: 1.5
# Negative score: 2.375
# Objective score: 21.125
# Overall Sentiment: Negative
#
# Review: Love it but it tore up shortly after I got it. I ordered two and they both tore at the part that connects to the metal. Great seller though. Very prompt.
# Rating: 3.0
# Positive score: 0.625
# Negative score: 0.0
# Objective score: 11.375
# Overall Sentiment: Positive
#
# Review: I love it it is just what I was looking for thank you!
# Rating: 5.0
# Positive score: 0.5
# Negative score: 0.0
# Objective score: 1.5
# Overall Sentiment: Positive
#
# Review: Quality product, I am very happy with my purchase.
# Rating: 5.0
# Positive score: 1.25
# Negative score: 0.0
# Objective score: 2.75
# Overall Sentiment: Positive
#
# Review: I like it except it is not quite big enough for the brand I smoke which is Salem Slim 100s.  They only come in the box type, I do tear the top of the box off but they still get a little smashed up at the filters.
# Rating: 4.0
# Positive score: 1.125
# Negative score: 1.25
# Objective score: 15.625
# Overall Sentiment: Negative
#
# Review: It is smaller than what I was expecting. The zipper compartment is not big enough .
# Rating: 3.0
# Positive score: 0.375
# Negative score: 0.5
# Objective score: 4.125
# Overall Sentiment: Negative
#
# Review: love it
# Rating: 5.0
# Positive score: 0.5
# Negative score: 0.0
# Objective score: 0.5
# Overall Sentiment: Positive
#
# Review: Don't like it. It will not hold my cigarettes. Not long enough.
# Rating: 1.0
# Positive score: 0.125
# Negative score: 0.0
# Objective score: 3.875
# Overall Sentiment: Positive
#
# Review: love
# Rating: 4.0
# Positive score: 0.625
# Negative score: 0.0
# Objective score: 0.375
# Overall Sentiment: Positive
#
# Review: Wonderful item. I have purchased several of these. They last forever unless you lose them.  I am happy with my purchase Buxton is made to last.
# Rating: 4.0
# Positive score: 1.75
# Negative score: 1.625
# Objective score: 7.625
# Overall Sentiment: Positive
#
# Review: I just love it! I think this is my six or seven case from Buxton. They are very stylish, durable and proper if you don't want your cigarette packet crushed inside your purse
# Rating: 5.0
# Positive score: 2.0
# Negative score: 0.125
# Objective score: 8.875
# Overall Sentiment: Positive
#
# Review: made well but will only hold a small pack of ciggs I don't smoke I use  this as a tip holder for work I bought a different one last year but it is falling apart so I replaced it with this brand.  The zipper compartment won't hold anything its to small
# Rating: 4.0
# Positive score: 0.625
# Negative score: 1.75
# Objective score: 18.625
# Overall Sentiment: Negative
#
# Review: I've ordered quite a few cases from Amazon and this one is my favorite!!
# Beautiful, slim and perfect for smaller handbags!
# Rating: 5.0
# Positive score: 2.125
# Negative score: 0.5
# Objective score: 6.375
# Overall Sentiment: Positive
#
# Review: Holds my cigarettes and it is durable and looks great.
# Rating: 5.0
# Positive score: 0.0
# Negative score: 0.0
# Objective score: 5.0
# Overall Sentiment: Neutral
#
# Review: Does not hold 120s to small for a lighter
# Rating: 1.0
# Positive score: 0.0
# Negative score: 0.375
# Objective score: 2.625
# Overall Sentiment: Negative
#
# Review: It fits my cigarettes, however very cheep material and smaller than the usual size of these. I would never purchase another one. It seems like a dollar store item
# Rating: 1.0
# Positive score: 0.875
# Negative score: 1.875
# Objective score: 10.25
# Overall Sentiment: Negative
#
# Review: Terrible quality
# Rating: 1.0
# Positive score: 0.375
# Negative score: 0.625
# Objective score: 1.0
# Overall Sentiment: Negative
#
# Review: nice but does not fit 100s
# Rating: 3.0
# Positive score: 0.75
# Negative score: 0.0
# Objective score: 1.25
# Overall Sentiment: Positive
#
# Review: Good quality
# Rating: 4.0
# Positive score: 1.125
# Negative score: 0.0
# Objective score: 0.875
# Overall Sentiment: Positive
#
# Review: I like the case.  A lighter fits in the opening without a problem
# Rating: 4.0
# Positive score: 0.125
# Negative score: 1.375
# Objective score: 4.5
# Overall Sentiment: Negative
# Review: I love it , it is the first one that I have found too fit the 120's cigerette's. Thanks so much for finding this case for me.
# Rating: 5.0
# Positive score: 1.625
# Negative score: 0.0
# Objective score: 7.375
# Overall Sentiment: Positive
#
# Review: I love it thank you
# Rating: 5.0
# Positive score: 0.5
# Negative score: 0.0
# Objective score: 0.5
# Overall Sentiment: Positive
#
# Review: nice but to small for my 100s cigs
# Rating: 3.0
# Positive score: 0.0
# Negative score: 0.375
# Objective score: 0.625
# Overall Sentiment: Negative
#
# Review: Says it fits 100s, nut does not
# Rating: 1.0
# Positive score: 0.5
# Negative score: 0.0
# Objective score: 1.5
# Overall Sentiment: Positive
#
# Review: The outside pocket isn't wide enough for my needs, but these are SO HARD TO FIND anymore.
# Rating: 4.0
# Positive score: 0.5
# Negative score: 1.0
# Objective score: 6.5
# Overall Sentiment: Negative
#
# Review: Excellent product!
# Rating: 5.0
# Positive score: 1.0
# Negative score: 0.0
# Objective score: 1.0
# Overall Sentiment: Positive
#
# Review: Excellent product and service! Thank you!
# Rating: 5.0
# Positive score: 1.0
# Negative score: 0.0
# Objective score: 2.0
# Overall Sentiment: Positive
#
# Review: Perfect cigarette case.  These are so hard to find anymore that I was delighted with it.
# Rating: 5.0
# Positive score: 1.25
# Negative score: 0.875
# Objective score: 3.875
# Overall Sentiment: Positive
#
# Review: Too small, and my lighter falls out all the time
# Rating: 3.0
# Positive score: 0.0
# Negative score: 0.625
# Objective score: 3.375
# Overall Sentiment: Negative
#
# Review: It's ok, It doesn't close if you have 100's
# Rating: 2.0
# Positive score: 0.375
# Negative score: 0.0
# Objective score: 1.625
# Overall Sentiment: Positive
#
# Review: Nice quality, but a little small for 100's.  Would be great for shorts.
# Rating: 4.0
# Positive score: 1.25
# Negative score: 0.75
# Objective score: 4.0
# Overall Sentiment: Positive
#
# Review: Exactly what I wanted. THANKS
# Rating: 5.0
# Positive score: 0.375
# Negative score: 0.0
# Objective score: 2.625
# Overall Sentiment: Positive
#
# Review: Just what I order,beru pleased.
# Rating: 5.0
# Positive score: 0.0
# Negative score: 0.0
# Objective score: 1.0
# Overall Sentiment: Neutral
#
# Review: all leather
# Rating: 5.0
# Positive score: 0.0
# Negative score: 0.0
# Objective score: 1.0
# Overall Sentiment: Neutral
#
# Review: This works so very good to keep your cig.. lighter ans anything else you may want to eep in it
# Rating: 5.0
# Positive score: 1.0
# Negative score: 0.0
# Objective score: 4.0
# Overall Sentiment: Positive
#
# Review: Perfect size and really nice!
# Rating: 5.0
# Positive score: 2.25
# Negative score: 0.5
# Objective score: 1.25
# Overall Sentiment: Positive
#
# Review: Awesome
# Rating: 5.0
# Positive score: 0
# Negative score: 0
# Objective score: 0
# Overall Sentiment: Neutral
#
# Review: Soft leather, very well made.
# Rating: 5.0
# Positive score: 0.375
# Negative score: 0.25
# Objective score: 3.375
# Overall Sentiment: Positive
#
# Review: great!!
# Rating: 5.0
# Positive score: 0.0
# Negative score: 0.0
# Objective score: 1.0
# Overall Sentiment: Neutral
#
# Review: Great
# Rating: 5.0
# Positive score: 0.0
# Negative score: 0.0
# Objective score: 1.0
# Overall Sentiment: Neutral
#
# Review: NOT GOOD FOR ME I THOUGHT IT WAS 100 PK
# Rating: 1.0
# Positive score: 0.75
# Negative score: 0.0
# Objective score: 1.25
# Overall Sentiment: Positive
#
# Review: Lining in lighter pocket tore within a very short time, had to dab a little contact adhesive between lining and leather to hold it in place and stop it bunching and snagging lighter. Purchased one black one brown, black one used most and has no centre seam down front lighter or rear coin pockets. Brown one has (pointless) decorative centre seam (as usually illustrated) front and rear. Front seam stitching has no reinforcing at lighter pocket opening. Looks likely to give trouble sooner rather than later. Leather is good and solid. Size is spot on for regular (84mm) packs of 20 (after a little use). O.k., But not the "premium product" I used to associate with the Buxton name many years ago.
# Rating: 3.0
# Positive score: 3.75
# Negative score: 3.75
# Objective score: 53.5
# Overall Sentiment: Neutral
#
# Review: Good product but not for 100's or 120's.
# Rating: 4.0
# Positive score: 0.75
# Negative score: 0.0
# Objective score: 1.25
# Overall Sentiment: Positive
#
# Review: Too small
# Rating: 1.0
# Positive score: 0.0
# Negative score: 0.375
# Objective score: 0.625
# Overall Sentiment: Negative
#
# Review: I like this case, but I smoke 100's and it is a little tighter fit than I would like. Otherwise it seems great quality
# Rating: 4.0
# Positive score: 0.625
# Negative score: 0.875
# Objective score: 8.5
# Overall Sentiment: Negative
#
# Review: Nice case but not really large enough for the 100's cigarettes
# Rating: 3.0
# Positive score: 1.875
# Negative score: 0.125
# Objective score: 4.0
# Overall Sentiment: Positive
#
# Review: Great buy...the case is very soft and fits kings only, which is what my mom wanted... only problem is shipping, it arrived over a week later than was promised because it was sent all over the US I stead of straight to me...
# Rating: 5.0
# Positive score: 2.125
# Negative score: 0.875
# Objective score: 13.0
# Overall Sentiment: Positive
#
# Review: Good, just what I expected.
# Rating: 4.0
# Positive score: 1.0
# Negative score: 0.25
# Objective score: 0.75
# Overall Sentiment: Positive
#
# Review: Bought this for my mom as hers was really worn out. Like the added addition of the zipper pocket!
# Rating: 4.0
# Positive score: 1.5
# Negative score: 0.0
# Objective score: 4.5
# Overall Sentiment: Positive
#
# Review: I had been looking for a replacement for a cigarette case I'd had for over 25 years and lost. After reviewing several I settled on this one. It was very well made, the leather was soft, not stiff or cheap looking. I loved the little front pocket that kept my lighter handy and easy to keep up with. There is even a small zippered pocket for change or whatever else. I was very pleased with it. Unfortunately, I had not read the description well enough and I discovered this case DOES NOT fit the 100's. It was such a nice case that I gave it to my daughter rather than return it. She has been more than pleased with it. I'm hoping the new one I have ordered is as nice.
# Rating: 5.0
# Positive score: 7.0
# Negative score: 4.5
# Objective score: 36.5
# Overall Sentiment: Positive
#
# Review: It's just what I wanted.
# Rating: 5.0
# Positive score: 0.25
# Negative score: 0.0
# Objective score: 0.75
# Overall Sentiment: Positive
#
# Review: Pretty wallet but to small for the cigarettes
# Rating: 3.0
# Positive score: 0.875
# Negative score: 0.5
# Objective score: 2.625
# Overall Sentiment: Positive
#
# Review: I was disappointed to find the my 100's won't fit in this case. Otherwise, it was exactly what I wanted. If there is a bigger one just like this, I wish someone would point it out to me. I'd buy it in a heartbeat!
# Rating: 3.0
# Positive score: 2.0
# Negative score: 0.875
# Objective score: 10.125
# Overall Sentiment: Positive
#
# Review: Is very small. Doesn't  fit my smokes...
# Rating: 2.0
# Positive score: 0.75
# Negative score: 0.375
# Objective score: 1.875
# Overall Sentiment: Positive
#
# Review: Worked great for my 100's I smoke.  Leather was supple and would definitely buy again. I wish It came in RED or PURPLE. Black is sooo hard to find in a black lined purse.
# Rating: 5.0
# Positive score: 0.625
# Negative score: 2.25
# Objective score: 13.125
# Overall Sentiment: Negative
#
# Review: Perfect leather cigarette case/purse, if you smoke the shorties. I gave this 4 stars because I didn't read the fine print where it said it will not accommodate Lights 100s aka the longer cigarettes.
# Rating: 4.0
# Positive score: 1.75
# Negative score: 0.25
# Objective score: 14.0
# Overall Sentiment: Positive
#
# Review: Hard to find and still the best
# Rating: 5.0
# Positive score: 0.75
# Negative score: 0.875
# Objective score: 2.375
# Overall Sentiment: Negative
#
# Review: a little to short but will work
# Rating: 4.0
# Positive score: 0.0
# Negative score: 1.0
# Objective score: 2.0
# Overall Sentiment: Negative
#
# Review: Purchased 2 cases, the quality of the leather is really good, I just wish the case was a little larger,once you put your cigarettes and lighter in the case you don't have any room
# to put anything in the little side zip pocket.
# Rating: 4.0
# Positive score: 2.375
# Negative score: 1.5
# Objective score: 16.125
# Overall Sentiment: Positive
#
# Review: doesn't fit 100's
# Rating: 2.0
# Positive score: 0.75
# Negative score: 0.0
# Objective score: 0.25
# Overall Sentiment: Positive
#
# Review: It does not fit 100's
# Rating: 2.0
# Positive score: 0.75
# Negative score: 0.0
# Objective score: 0.25
# Overall Sentiment: Positive
#
# Review: This product is not a good fit as it does not hold 100s, so I have to send it back.
# Rating: 1.0
# Positive score: 0.75
# Negative score: 0.5
# Objective score: 4.75
# Overall Sentiment: Positive
#
# Review: Love this case I have had about 10 of them over the years so glad you carry them
# Rating: 5.0
# Positive score: 0.625
# Negative score: 0.625
# Objective score: 3.75
# Overall Sentiment: Neutral
#
# Review: I ordered black got brown not happy!
# Rating: 1.0
# Positive score: 1.0
# Negative score: 0.375
# Objective score: 2.625
# Overall Sentiment: Positive
#
# Review: Buxton has always used quality leather in all of the products they have offered over the years and they still do. The case is very well constructed and should last many years.
# Rating: 5.0
# Positive score: 0.75
# Negative score: 0.375
# Objective score: 12.875
# Overall Sentiment: Positive
#
# Review: barely holds a pack of 100's but would be better if i smoked regulars
# Rating: 4.0
# Positive score: 0.5
# Negative score: 0.25
# Objective score: 5.25
# Overall Sentiment: Positive
#
# Review: Very pleased with this cigarette case. I've had the exact same one before but I lost it. It holds up really well compared to some other cases I've owned. You won't be sorry if you purchase this and the price is right.
# Rating: 5.0
# Positive score: 1.625
# Negative score: 1.25
# Objective score: 11.125
# Overall Sentiment: Positive
#
# Review: Perfect and durable. I love the look and feel of this case. I have purchased two different colors and considering a third. Love it!
# Rating: 5.0
# Positive score: 1.875
# Negative score: 0.0
# Objective score: 10.125
# Overall Sentiment: Positive
# Review: Great value at price.
# Rating: 4.0
# Positive score: 0.0
# Negative score: 0.0
# Objective score: 3.0
# Overall Sentiment: Neutral
#
# Review: Well made, nice leather too!
# Rating: 5.0
# Positive score: 1.25
# Negative score: 0.0
# Objective score: 1.75
# Overall Sentiment: Positive
#
# Review: IT IS ATTRACTIVE, BUT IT'S ON THE SMALL SIDE. MY CIGARETTES DO FIT IN THERE, BUT WITH FORCING. THE LONGER THAT I USE IT, THE MORE IT STRETCHES OUT SOME. IT'S NOT AS TIGHT AS IN THE BEGINNING.
# Rating: 3.0
# Positive score: 0.0
# Negative score: 0.375
# Objective score: 8.625
# Overall Sentiment: Negative
#
# Review: I bought this for a relative of mine. I haven't seen it as I sent it to her in another state. But She said that she really likes it, is very happy with it. Its just what she wanted.  it is made very well.
# Rating: 5.0
# Positive score: 2.125
# Negative score: 0.0
# Objective score: 9.875
# Overall Sentiment: Positive
#
# Review: I cannot believe this case cost as little as it did.  I was skeptical of what the quality was going to be like after I ordered it.  When I received it I was amazed because it is real leather and it looks fabulous.  It is a little snug if you try to put a hard pack in it but all you have to do is tear off the top off the cigarettes and they fit.
#
# GREAT BUY
# Rating: 5.0
# Positive score: 2.75
# Negative score: 2.5
# Objective score: 20.75
# Overall Sentiment: Positive
#
# Review: I ordered the Buxton Heiress collection Black  Leather cigarette Case with lighter pocket, instead I received Urban Express Sandra Framed Wallet, Pewter, the  wallet is mismarked, The code bar on the wallet is for  the Buxton Cigarette case, just wrong merchandise, I am returning it in exchange for the Black Heiress collection cigarette case that I ordered, as for your merchandise I am very happy with it,
# Rating: 5.0
# Positive score: 1.0
# Negative score: 1.875
# Objective score: 29.125
# Overall Sentiment: Negative
#
# Review: The material did not feel like leather at all.  Felt very cheap and plasticy and like it would rip very easily.  Returned this.
# The seller however was great - very quick shipping and return processing.
# Rating: 1.0
# Positive score: 0.75
# Negative score: 1.0
# Objective score: 11.25
# Overall Sentiment: Negative
#
# Review: would not hold box she did not like it too small
# would not tell anyone else to buy this product
# Rating: 1.0
# Positive score: 0.0
# Negative score: 0.375
# Objective score: 5.625
# Overall Sentiment: Negative
#
# Review: Bought this for my wife and did not read the fine print. I thought it safe to assume a women's cigarette case would hold 100's. Not the case (pardon the punn). so I had to return this and buy the correct size which of course can be found on Amazon.
# Rating: 1.0
# Positive score: 1.0
# Negative score: 1.125
# Objective score: 17.875
# Overall Sentiment: Negative
#
# Review: This was a gift, and the recipient loved it. It suits the purpose it was intended for when I purchased it.
# Rating: 4.0
# Positive score: 1.0
# Negative score: 0.0
# Objective score: 5.0
# Overall Sentiment: Positive
#
# Review: this was a gift and the party was very happy with it  only if could be a little larger for larger pkg. .leather was  very soft.
# Rating: 5.0
# Positive score: 1.625
# Negative score: 0.875
# Objective score: 4.5
# Overall Sentiment: Positive
#
# Review: Smaller than my previous case that was the same brand ect...  Quality is good as always. Just wish it had been larger.
# Rating: 3.0
# Positive score: 1.5
# Negative score: 0.875
# Objective score: 7.625
# Overall Sentiment: Positive
#
# Review: I use the same case for my smokes. the last one lasted 6 years that's why I always buy this one! love it
# Rating: 5.0
# Positive score: 0.5
# Negative score: 0.5
# Objective score: 9.0
# Overall Sentiment: Neutral
#
# Review: We tried these shirts in the pinpoint fabric, but after washing they are the worst wrinkled shirt I have ever tried.  I have a steam dryer and it looks like it was rolled into a ball wet and then dried, awful!  The quality is fine, but if you iron your own shirts beware.  Probably okay if you use the cleaners.
# Rating: 1.0
# Positive score: 1.0
# Negative score: 1.625
# Objective score: 22.375
# Overall Sentiment: Negative
#
# Review: Hard to find shirts that are not non-iron (which don't hold up well to commercial laundering) anymore. These are good.
# Rating: 5.0
# Positive score: 1.125
# Negative score: 0.75
# Objective score: 8.125
# Overall Sentiment: Positive
#
# Review: Below average for the money.  The button holes are poorly finished and the fabric is thin enough that you'll want to wear an undershirt.  I have no doubt it'll shrink badly if washed.  There is NO wrinkle control so it arrived folded but looked like an old rag when unpackaged.  This just adds to the fact it's cheap material.  I see this as a dry clean only occasional use dress shirt.
#
# The sad thing is their other shirts may use better material but if they don't and I paid $69 for a shirt of this quality I'd return it.  My search continues for a good quality dress shirt at a reasonable price!
# Rating: 2.0
# Positive score: 3.625
# Negative score: 2.875
# Objective score: 42.5
# Overall Sentiment: Positive
#
# Review: The fit was a bit awkward for my athletic body type.  Fabric quality overall is good.
# Rating: 3.0
# Positive score: 1.125
# Negative score: 0.625
# Objective score: 6.25
# Overall Sentiment: Positive
#
# Review: Great style with quality fabric and nice fit
# Rating: 5.0
# Positive score: 1.25
# Negative score: 0.5
# Objective score: 4.25
# Overall Sentiment: Positive
